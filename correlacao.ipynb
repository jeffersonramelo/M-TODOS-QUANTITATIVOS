# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersonramelo/M-TODOS-QUANTITATIVOS/blob/main/correlacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/tempo e notas.csv', sep=';')
print(df.head())


    # Calcular a correlação de Pearson
correlation_matrix = df.corr(method='pearson')

print("Matriz de Correlação de Pearson:")
print(correlation_matrix)
# Out:
#    Notas  TempoSono  TempoRev
# 0      2         12         1
# 1      2         12         1
# 2      2         12         1
# 3      2         12         1
# 4      2         12         1
# Matriz de Correlação de Pearson:
#               Notas  TempoSono  TempoRev
# Notas      1.000000  -0.762779  0.980109
# TempoSono -0.762779   1.000000 -0.822819
# TempoRev   0.980109  -0.822819  1.000000

# %%
import pandas as pd

df = pd.read_csv('/content/publicidade e vendas.csv', sep=';')
print(df.head())


    # Calcular a correlação de Pearson
correlation_matrix = df.corr(method='pearson')

print("Matriz de Correlação de Pearson:")
print(correlation_matrix)
# Out:
#    Publicidade  Vendas  d_teste1  d_teste0  p_v_t_1  p_v_t_0
# 0          986     120         1         0   118320        0
# 1         1446     360         0         1        0   520560
# 2         1188     270         1         0   320760        0
# 3          575     220         0         1        0   126500
# 4          569     170         1         0    96730        0
# Matriz de Correlação de Pearson:
#              Publicidade    Vendas  d_teste1  d_teste0   p_v_t_1   p_v_t_0
# Publicidade     1.000000  0.602875  0.006764 -0.006764  0.425229  0.634556
# Vendas          0.602875  1.000000  0.000608 -0.000608  0.337974  0.529851
# d_teste1        0.006764  0.000608  1.000000 -1.000000  0.647211 -0.539899
# d_teste0       -0.006764 -0.000608 -1.000000  1.000000 -0.647211  0.539899
# p_v_t_1         0.425229  0.337974  0.647211 -0.647211  1.000000 -0.349428
# p_v_t_0         0.634556  0.529851 -0.539899  0.539899 -0.349428  1.000000
