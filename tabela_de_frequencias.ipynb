# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersonramelo/M-TODOS-QUANTITATIVOS/blob/main/tabela_de_frequencias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Lendo o arquivo CSV
df = pd.read_csv('/content/exercicio02frequencias.csv', sep=';')

# Exibindo as primeiras linhas do DataFrame
df
# Out:
#                sexo desempenho  renda  filhos
# 0         masculino       alto      1       1
# 1          feminino       alto      1       1
# 2           nao sei       alto      1       1
# 3     nao informado      medio      1       1
# 4          feminino      medio      1       0
# ...             ...        ...    ...     ...
# 4995       feminino      medio   3000       0
# 4996       feminino      baixo   3000       0
# 4997       feminino      baixo   3000       0
# 4998      masculino      baixo   3000       0
# 4999      masculino      medio   3000       2
#
# [5000 rows x 4 columns]

# %% [markdown]
# Tabela de frequências para variáveis QUALITATIVAS e  QUANTITATIVAS_SEM ORGANIZAÇÃO EM CLASSES
#
# ---

# %%
# Frequência Simples (FS)
fs = df['filhos'].value_counts()

# Frequência Acumulada (FA)
fa = fs.cumsum()

# Frequência Relativa Simples (FRS) - Convertendo para porcentagem
frs = (fs / fs.sum()) * 100

# Frequência Relativa Acumulada (FRA)
fra = frs.cumsum()

# Criando um novo DataFrame para a tabela de distribuição de frequência
tabela_frequencia = pd.DataFrame({
    'Frequência Simples': fs,
    'Frequência Acumulada': fa,
    'Frequência Relativa Simples (%)': frs,
    'Frequência Relativa Acumulada (%)': fra
})

tabela_frequencia
# Out:
#         Frequência Simples  Frequência Acumulada  \
# filhos
# 1                     1668                  1668
# 0                     1668                  3336
# 2                      832                  4168
# 4                      416                  4584
# 5                      416                  5000
#
#         Frequência Relativa Simples (%)  Frequência Relativa Acumulada (%)
# filhos
# 1                                 33.36                              33.36
# 0                                 33.36                              66.72
# 2                                 16.64                              83.36
# 4                                  8.32                              91.68
# 5                                  8.32                             100.00

# %% [markdown]
# Salvando a tabela em Excel

# %%
# Continuando do código anterior após a criação da tabela_frequencia

# Salvando a tabela em um arquivo Excel
tabela_frequencia.to_excel('distribuicao_frequencia_filhos.xlsx', index=False, engine='openpyxl')

# %% [markdown]
# Tabela de frequências para variáveis QUANTITATIVAS_COM ORGANIZAÇÃO EM CLASSES

# %%
df['renda'].describe()
# Out:
# count    5000.000000
# mean      825.042400
# std      1061.049293
# min         1.000000
# 25%        47.000000
# 50%       153.000000
# 75%      1500.000000
# max      3000.000000
# Name: renda, dtype: float64

# %%
import pandas as pd

# Supondo que seu DataFrame seja 'df' e já foi carregado com pd.read_csv()

# Definindo as classes de renda
bins = [0, 400, 800, float('inf')]  # O último intervalo vai de 800 até infinito
labels = ['0 a 400', '400 a 800', '800 a 3000']
df['Classe de Renda'] = pd.cut(df['renda'], bins=bins, labels=labels, right=False)

# Frequência Simples (FS)
fs = df['Classe de Renda'].value_counts().sort_index()

# Frequência Acumulada (FA)
fa = fs.cumsum()

# Frequência Relativa Simples (FRS) - Convertendo para porcentagem
frs = (fs / fs.sum()) * 100

# Frequência Relativa Acumulada (FRA)
fra = frs.cumsum()

# Criando um novo DataFrame para a tabela de distribuição de frequência
tabela_frequencia = pd.DataFrame({
    'Frequência Simples': fs,
    'Frequência Acumulada': fa,
    'Frequência Relativa Simples (%)': frs,
    'Frequência Relativa Acumulada (%)': fra
})

print(tabela_frequencia)
# Out:
#   Classe de Renda  Frequência Simples  Frequência Acumulada  \
# 0         0 a 400                3035                  3035
# 1       400 a 800                 108                  3143
# 2      800 a 3000                1857                  5000
#
#    Frequência Relativa Simples (%)  Frequência Relativa Acumulada (%)
# 0                            60.70                              60.70
# 1                             2.16                              62.86
# 2                            37.14                             100.00

# %%
# Continuando do código anterior após a criação da tabela_frequencia

# Salvando a tabela em um arquivo Excel
tabela_frequencia.to_excel('distribuicao_frequencia_renda.xlsx', index=False, engine='openpyxl')
